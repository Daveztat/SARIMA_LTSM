# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
from statsmodels.tsa.arima_process import ArmaProcess

# %matplotlib inline

# %%
np.random.seed(42) 
ma2 = np.array([1, 0.9, 0.3])
ar2 = np.array([1, 0, 0])

MA2_process = ArmaProcess(ar2, ma2).generate_sample(nsample=1000)

# %%
fig, ax = plt.subplots()

ax.plot(MA2_process)
ax.set_title("MA(2) Simulado")
# Out:
# Text(0.5, 1.0, 'MA(2) Simulado')

# %%
from statsmodels.tsa.stattools import adfuller

# %%
Dk = adfuller(MA2_process)
Dk
# Out:
# (-14.00544430919449,
#  3.795601616713556e-26,
#  3,
#  996,
#  {'1%': -3.4369325637409154,
#   '5%': -2.8644462162311934,
#   '10%': -2.568317409920808},
#  2739.7287503892885)

# %%
from statsmodels.graphics.tsaplots import plot_acf

# %%
plot_acf(MA2_process);

# %%
train, test = MA2_process[:800], MA2_process[800:]
